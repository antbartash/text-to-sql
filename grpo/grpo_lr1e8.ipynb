# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import torch
import datasets
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    EarlyStoppingCallback
)
from transformers.trainer_utils import get_last_checkpoint
from trl import GRPOConfig, GRPOTrainer
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
import evaluate
import wandb
from datetime import datetime
import time
from tqdm.auto import tqdm
import sqlite3
import sqlparse
import _config

import os
import psutil
import GPUtil
import gc


# Set the verbosity to WARNING to suppress INFO messages
evaluate.logging.set_verbosity_warning()

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
os.environ["WANDB_API_KEY"] = _config.WANDB_API_KEY
os.environ["WANDB_PROJECT"] = _config.WANDB_PROJECT

ENABLE_THINKING = False
# Out:
# 2026-01-22 20:26:42.041572: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-01-22 20:27:00] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-22 20:27:00] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-22 20:27:00] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-22 20:27:00] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-22 20:27:00] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-22 20:27:01] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"

# %% [markdown]
# # Utils

# %%
def get_vm_usage_metrics():
    # CPU usage
    cpu_load = psutil.cpu_percent(interval=1, percpu=True)
    for id, load in enumerate(cpu_load):
        print(f"CPU {id} load: {load:.2f}")
    # RAM usage
    ram = psutil.virtual_memory()
    print(f"RAM Total: {ram.total/(1024**3):.2f} GB, Used: {(ram.used)/(1024**3):.2f} GB")
    # GPU
    if torch.cuda.is_available():
        gpus = GPUtil.getGPUs()
        for gpu in gpus:
            print(f"GPU {gpu.id} ({gpu.name}) load: {gpu.load*100}%")
            print(f"GPU {gpu.id} ({gpu.name}) VRAM Total: {gpu.memoryTotal} MB, Used {gpu.memoryUsed} MB")
    # Disk 
    disk = psutil.disk_usage('/')
    print(f"Disk Total: {disk.total/(1024**3):.2f} GB, Used: {(disk.used)/(1024**3):.2f} GB")

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f'Device: {device}')
get_vm_usage_metrics()
# Out:
# Device: cuda
# CPU 0 load: 0.00
# CPU 1 load: 0.00
# CPU 2 load: 1.00
# CPU 3 load: 0.00
# RAM Total: 27.40 GB, Used: 1.88 GB
# GPU 0 (Tesla T4) load: 0.0%
# GPU 0 (Tesla T4) VRAM Total: 16384.0 MB, Used 3.0 MB
# Disk Total: 60.95 GB, Used: 48.41 GB

# %%
def generate_model_response_batch(model, tokenizer, messages_list, enable_thinking=False, max_new_tokens=512):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=enable_thinking
        )
        for messages in messages_list
    ]

    model_inputs = tokenizer(
        texts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        padding_side='left'
    ).to(model.device)

    model.eval()
    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=max_new_tokens
    )

    responses = []
    for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids):
        # Slice to get only generated part
        output_only_ids = output_ids[len(input_ids):].tolist()

        # Try to find `</think>` (id 151668)
        try:
            index = len(output_only_ids) - output_only_ids[::-1].index(151668)
        except ValueError:
            index = 0

        if enable_thinking:
            thinking_content = tokenizer.decode(
                output_only_ids[:index],
                skip_special_tokens=True
            ).strip("\n")
            content = tokenizer.decode(
                output_only_ids[index:],
                skip_special_tokens=True
            ).strip("\n")
        else:
            thinking_content = None
            content = tokenizer.decode(
                output_only_ids,
                skip_special_tokens=True
            ).strip("\n")

        responses.append({
            'thinking_content': thinking_content,
            'content': content
        })

    return responses

# %% [markdown]
# # Data

# %%
ds = datasets.load_dataset('gretelai/synthetic_text_to_sql', streaming=False)
ds_train, ds_test = ds['train'], ds['test']

ds_train_subset = ds_train.train_test_split(test_size=0.1, seed=42)['test']
split = ds_train_subset.train_test_split(test_size=0.025, seed=42)
ds_train = split['train']
ds_valid = split['test']

ds_train
# Out:
# Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#     num_rows: 9750
# })

# %%
# datasets for GRPO must include a column "prompt"
def construct_message(example):
    return {"prompt": [
        {"role": "system", "content": f"The user asks a question. Your task is to generate the SQL query to answer that question. Return SQL query only. The context of the question is the following: '{example['sql_context']}'"},
        {"role": "user", "content": example['sql_prompt']}
    ]}
ds_train = ds_train.map(construct_message)
ds_valid = ds_valid.map(construct_message)

# rename the ground_truth column
ds_train = ds_train.rename_column("sql", "ground_truth")
ds_valid = ds_valid.rename_column("sql", "ground_truth")

ds_train
# Out:
# Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'ground_truth', 'sql_explanation', 'prompt'],
#     num_rows: 9750
# })

# %% [markdown]
# # Reward function

# %%
rouge = evaluate.load("rouge")

def normalize_sql(sql):
    return sqlparse.format(sql, reindent=True, keyword_case='upper').strip()

def compute_rouge(reference, prediction):
    result = rouge.compute(predictions=[prediction], references=[reference])
    return result['rougeL']


def evaluate_sql_response(reference, prediction, sql_context):
    # ROUGE-L
    rouge_score = compute_rouge(reference, prediction)

    for ref, pred,  in zip(reference, prediction):
        # execution check
        try:
            conn = sqlite3.connect(":memory:")
            cursor = conn.cursor()
            
            cursor.executescript(sql_context)
            cursor.execute(reference)
            ref_result = cursor.fetchall()
            
            cursor.execute(prediction)
            model_result = cursor.fetchall()
            
            execution_match = ref_result == model_result
        except Exception:
            execution_match = False
        finally:
            conn.close()
        
        # final score
        if execution_match:
            final_score = 1.0
        else:
            final_score = 0.7 * rouge_score

    return {
        "rougeL": round(rouge_score, 4),
        "execution_match": execution_match,
        "final_score": final_score
    }


def reward_func(completions, ground_truth, sql_context, **kwargs):
    scores = [
        evaluate_sql_response(
            reference=reference,
            prediction=prediction[0]["content"],
            sql_context=context
        )["final_score"]
        for reference, prediction, context in zip(ground_truth, completions, sql_context)
    ]
    return scores

# %% [markdown]
# # Model

# %%
checkpoint = "Qwen/Qwen3-0.6B"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

tokenizer = AutoTokenizer.from_pretrained(checkpoint, padding_side='left')

model = AutoModelForCausalLM.from_pretrained(
    checkpoint,
    # attn_implementation="sdpa",
    device_map="auto",
    dtype=torch.float32,
    # quantization_config=bnb_config
)

model.config.use_cache = False
model.gradient_checkpointing_enable()
# model = prepare_model_for_kbit_training(model)
model.enable_input_require_grads()

get_vm_usage_metrics()
# Out:
# [2026-01-22 20:27:19] INFO modeling.py:1004: We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# CPU 0 load: 0.00
# CPU 1 load: 0.00
# CPU 2 load: 0.00
# CPU 3 load: 0.00
# RAM Total: 27.40 GB, Used: 2.10 GB
# GPU 0 (Tesla T4) load: 0.0%
# GPU 0 (Tesla T4) VRAM Total: 16384.0 MB, Used 3063.0 MB
# Disk Total: 60.95 GB, Used: 48.41 GB

# %% [markdown]
# # GRPO

# %%
torch.cuda.empty_cache()

# timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
timestamp = '2026-01-21_08-52-33'
RUN_NAME = f'grpo-lora-lr1e8-clip3-epochs1-{timestamp}'
OUTPUT_DIR = './grpo-lr1e8-clip3-output'
RESUME_TRAINING = True

PER_DEVICE_BATCH_SIZE = 8
effective_batch_size = 16
epochs=1
learning_rate = 1e-8 # changed from 1e-5
warmup_ratio = 0.1
lora_r = 16*4
lora_alpha = 64*4
lora_dropout = 0.01

gradient_accumulation_steps = int(effective_batch_size / PER_DEVICE_BATCH_SIZE)

wandb.init(
    project=os.environ["WANDB_PROJECT"],
    name=RUN_NAME,
    id='syou0fj2' ,         # resume previous run if available
    resume="allow",    # allows resuming crashed run
)



training_args = GRPOConfig(
    output_dir=OUTPUT_DIR,
    
    chat_template_kwargs = {"enable_thinking": False},
    num_train_epochs=epochs,
    num_generations=8,
    # use_liger_kernel=True,
    
    per_device_train_batch_size=PER_DEVICE_BATCH_SIZE,
    gradient_accumulation_steps=gradient_accumulation_steps,
    learning_rate=learning_rate,
    lr_scheduler_type="cosine",
    warmup_ratio=warmup_ratio,
    save_strategy="steps",
    save_steps=30,
    save_total_limit=2,
    eval_strategy="steps",
    eval_steps=30,
    per_device_eval_batch_size=PER_DEVICE_BATCH_SIZE*4,
    eval_accumulation_steps=1,
    # eval_kwargs={"num_generations": 1},
    num_generations_eval=1,
    logging_strategy="steps",
    logging_steps=30,
    report_to=['wandb'],
    run_name=RUN_NAME,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    max_grad_norm=0.3,
    load_best_model_at_end=True,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    # generate_during_eval=True
)

peft_config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules='all-linear'
)
# model.requires_grad_(False)                     # freeze base weights (precautionary)
model_peft = get_peft_model(model, peft_config) # inject a LoRA adapter

trainer = GRPOTrainer(
    processing_class=tokenizer,
    model=model_peft,
    args=training_args,
    reward_funcs=[reward_func],
    train_dataset=ds_train,
    eval_dataset=ds_valid,
    # callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)


# Training setup summary
dataset_size = len(ds_train)
steps_per_epoch = dataset_size // (PER_DEVICE_BATCH_SIZE * gradient_accumulation_steps)
total_steps = steps_per_epoch * epochs
warmup_steps = int(total_steps * warmup_ratio)

print("===== Training Setup Summary =====")
print(f"Num epochs:            {epochs}")
print(f"Effective batch size:  {effective_batch_size}")
print(f"Per-device batch size: {PER_DEVICE_BATCH_SIZE}")
print(f"Gradient accumulation: {gradient_accumulation_steps}")
print(f"Dataset size:          {dataset_size}")
print(f"Steps per epoch:       {steps_per_epoch}")
print(f"Total training steps:  {total_steps}")
print(f"Warmup steps:          {warmup_steps}")
print(f"Logging steps:         {training_args.logging_steps}")
print("===================================")
print(f"Start time: {datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}")


# Training
last_checkpoint = None
if RESUME_TRAINING and os.path.isdir(OUTPUT_DIR):
    last_checkpoint = get_last_checkpoint(OUTPUT_DIR)

if last_checkpoint is not None:
    print(f"Resuming training from checkpoint: {last_checkpoint}")
    trainer.train(resume_from_checkpoint=last_checkpoint)
else:
    print("Starting fresh training run")
    trainer.train()

print(f"End time: {datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}")
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: olialeshka (olialeshka-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/olialeshka_1/wandb/run-20260122_202751-syou0fj2</code>
# Resuming run <strong><a href='https://wandb.ai/olialeshka-none/text-to-sql/runs/syou0fj2' target="_blank">grpo-lora-lr1e8-clip3-epochs1-2026-01-21_08-52-33</a></strong> to <a href='https://wandb.ai/olialeshka-none/text-to-sql' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/olialeshka-none/text-to-sql' target="_blank">https://wandb.ai/olialeshka-none/text-to-sql</a>
#  View run at <a href='https://wandb.ai/olialeshka-none/text-to-sql/runs/syou0fj2' target="_blank">https://wandb.ai/olialeshka-none/text-to-sql/runs/syou0fj2</a>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# [2026-01-22 20:27:56] INFO spawn.py:77: x86_64-linux-gnu-gcc -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -fPIC -c /tmp/tmpkst2v_5n/test.c -o /tmp/tmpkst2v_5n/test.o
# [2026-01-22 20:27:57] INFO spawn.py:77: x86_64-linux-gnu-gcc /tmp/tmpkst2v_5n/test.o -laio -o /tmp/tmpkst2v_5n/a.out
# /usr/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# [2026-01-22 20:27:57] INFO spawn.py:77: x86_64-linux-gnu-gcc -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -fPIC -c /tmp/tmpf1v7gll6/test.c -o /tmp/tmpf1v7gll6/test.o
# [2026-01-22 20:27:57] INFO spawn.py:77: x86_64-linux-gnu-gcc /tmp/tmpf1v7gll6/test.o -L/usr -L/usr/lib64 -lcufile -o /tmp/tmpf1v7gll6/a.out
# /usr/bin/ld: cannot find -lcufile: No such file or directory
# collect2: error: ld returned 1 exit status
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# ===== Training Setup Summary =====
# Num epochs:            1
# Effective batch size:  16
# Per-device batch size: 8
# Gradient accumulation: 2
# Dataset size:          9750
# Steps per epoch:       609
# Total training steps:  609
# Warmup steps:          60
# Logging steps:         30
# ===================================
# Start time: 2026-01-22_20-27-58
# Resuming training from checkpoint: ./grpo-lr1e8-clip3-output/checkpoint-4320
# [2026-01-22 20:28:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:18] INFO rouge_scorer.py:83: Using default tokenizer.
#     <div>
#
#       <progress value='4351' max='4875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4351/4875 05:55 < 1:47:10, 0.08 it/s, Epoch 0.89/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/8 : < :]
#     </div>
# [2026-01-22 20:28:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:28:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:31:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:32:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:33:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:34:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:35:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-22 20:35:00] INFO rouge_scorer.py:83: Using default tokenizer.

# %%
# model.save_pretrained(f"{OUTPUT_DIR}/best_model")

# %% [markdown]
# # Test

# %%
OUTPUT_DIR = './grpo-lr1e8-clip3-output'
checkpoint = f"{OUTPUT_DIR}/checkpoint-4875/"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint, dtype=torch.float16).to(device)
model.eval()

ds = datasets.load_dataset('gretelai/synthetic_text_to_sql', streaming=False)
ds_train, ds_test = ds['train'], ds['test']


def construct_message(prompt, context):
    return [
        {"role": "system", "content": f"The user asks a question. Your task is to generate the SQL query to answer that question. Return SQL query only. The context of the question is the following: '{context}'"},
        {"role": "user", "content": prompt}
    ]

def generate_model_response_batch(messages_list, enable_thinking=True, max_new_tokens=512):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=enable_thinking
        )
        for messages in messages_list
    ]

    model_inputs = tokenizer(
        texts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        padding_side='left'
    ).to(model.device)

    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=max_new_tokens
    )

    responses = []
    for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids):
        # Slice to get only generated part
        output_only_ids = output_ids[len(input_ids):].tolist()

        # Try to find `</think>` (id 151668)
        try:
            index = len(output_only_ids) - output_only_ids[::-1].index(151668)
        except ValueError:
            index = 0

        if enable_thinking:
            thinking_content = tokenizer.decode(
                output_only_ids[:index],
                skip_special_tokens=True
            ).strip("\n")
            content = tokenizer.decode(
                output_only_ids[index:],
                skip_special_tokens=True
            ).strip("\n")
        else:
            thinking_content = None
            content = tokenizer.decode(
                output_only_ids,
                skip_special_tokens=True
            ).strip("\n")

        responses.append({
            'thinking_content': thinking_content,
            'content': content
        })

    return responses


rouge = evaluate.load("rouge")

def normalize_sql(sql):
    return sqlparse.format(sql, reindent=True, keyword_case='upper').strip()

def compute_rouge(reference, prediction):
    result = rouge.compute(predictions=[prediction], references=[reference])
    return result['rougeL']

def evaluate_sql_response(reference, prediction, sql_context):
    # ROUGE-L
    rouge_score = compute_rouge(reference, prediction)
    
    # execution check
    try:
        conn = sqlite3.connect(":memory:")
        cursor = conn.cursor()
        
        cursor.executescript(sql_context)
        cursor.execute(reference)
        ref_result = cursor.fetchall()
        
        cursor.execute(prediction)
        model_result = cursor.fetchall()
        
        execution_match = ref_result == model_result
    except Exception:
        execution_match = False
    finally:
        conn.close()
    
    # final score
    if execution_match:
        final_score = 1.0
    else:
        final_score = 0.7 * rouge_score

    return {
        "rougeL": round(rouge_score, 4),
        "execution_match": execution_match,
        "final_score": final_score
    }

# %%
BATCH_SIZE = 32
ENABLE_THINKING = False
MAX_NEW_TOKENS = 512


prompts = [ds_test[id]['sql_prompt'] for id in range(len(ds_test))]
contexts = [ds_test[id]['sql_context'] for id in range(len(ds_test))]

responses = []
print(f"Start time: {time.ctime(time.time())}")
for i in tqdm(range(0, len(prompts), BATCH_SIZE)):
    batch_prompts = prompts[i : i + BATCH_SIZE]
    batch_contexts = contexts[i : i + BATCH_SIZE]

    messages_list = [
        construct_message(prompt=p, context=c)
        for p, c in zip(batch_prompts, batch_contexts)
    ]

    batch_responses = generate_model_response_batch(messages_list, enable_thinking=ENABLE_THINKING, max_new_tokens=MAX_NEW_TOKENS)

    responses.extend(batch_responses)

print(f"End time: {time.ctime(time.time())}")
# Out:
# Start time: Fri Jan 23 07:05:53 2026
#   0%|          | 0/183 [00:00<?, ?it/s]
# End time: Fri Jan 23 07:29:52 2026

# %%
references = [ds_test[id]['sql'] for id in range(len(ds_test))]
predictions = [responses[id]['content'] for id in range(len(ds_test))]

scores = [
    evaluate_sql_response(
        reference=reference,
        prediction=prediction,
        sql_context=context
    )
    for reference, prediction, context in tqdm(zip(references, predictions, contexts), total=len(ds_test))
]
# Out:
#   0%|          | 0/5851 [00:00<?, ?it/s]
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:29:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:30:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:31:08] INFO rouge_scorer.py:83: Using default tokenizer.
# ...
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-23 07:40:57] INFO rouge_scorer.py:83: Using default tokenizer.

# %%
print(f"Mean test set score: {np.mean([score['final_score'] for score in scores]):.3f}")
# Out:
# Mean test set score: 0.696
