# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import torch
import datasets
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    EarlyStoppingCallback
)
from transformers.trainer_utils import get_last_checkpoint
from trl import GRPOConfig, GRPOTrainer
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
import evaluate
import wandb
from datetime import datetime
import time
from tqdm.auto import tqdm
import sqlite3
import sqlparse
import _config

import os
import psutil
import GPUtil
import gc


# Set the verbosity to WARNING to suppress INFO messages
evaluate.logging.set_verbosity_warning()

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
os.environ["WANDB_API_KEY"] = _config.WANDB_API_KEY
os.environ["WANDB_PROJECT"] = _config.WANDB_PROJECT

ENABLE_THINKING = False
# Out:
# 2026-01-19 12:58:26.216399: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-01-19 12:58:51] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-19 12:58:51] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-19 12:58:52] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-19 12:58:52] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-19 12:58:52] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# [2026-01-19 12:58:52] INFO _client.py:1025: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"

# %% [markdown]
# # Utils

# %%
def get_vm_usage_metrics():
    # CPU usage
    cpu_load = psutil.cpu_percent(interval=1, percpu=True)
    for id, load in enumerate(cpu_load):
        print(f"CPU {id} load: {load:.2f}")
    # RAM usage
    ram = psutil.virtual_memory()
    print(f"RAM Total: {ram.total/(1024**3):.2f} GB, Used: {(ram.used)/(1024**3):.2f} GB")
    # GPU
    if torch.cuda.is_available():
        gpus = GPUtil.getGPUs()
        for gpu in gpus:
            print(f"GPU {gpu.id} ({gpu.name}) load: {gpu.load*100}%")
            print(f"GPU {gpu.id} ({gpu.name}) VRAM Total: {gpu.memoryTotal} MB, Used {gpu.memoryUsed} MB")
    # Disk 
    disk = psutil.disk_usage('/')
    print(f"Disk Total: {disk.total/(1024**3):.2f} GB, Used: {(disk.used)/(1024**3):.2f} GB")

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f'Device: {device}')
get_vm_usage_metrics()
# Out:
# Device: cuda
# CPU 0 load: 0.00
# CPU 1 load: 0.00
# CPU 2 load: 2.00
# CPU 3 load: 0.00
# RAM Total: 27.40 GB, Used: 1.91 GB
# GPU 0 (Tesla T4) load: 0.0%
# GPU 0 (Tesla T4) VRAM Total: 16384.0 MB, Used 3.0 MB
# Disk Total: 60.95 GB, Used: 45.47 GB

# %%
def generate_model_response_batch(model, tokenizer, messages_list, enable_thinking=False, max_new_tokens=512):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=enable_thinking
        )
        for messages in messages_list
    ]

    model_inputs = tokenizer(
        texts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        padding_side='left'
    ).to(model.device)

    model.eval()
    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=max_new_tokens
    )

    responses = []
    for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids):
        # Slice to get only generated part
        output_only_ids = output_ids[len(input_ids):].tolist()

        # Try to find `</think>` (id 151668)
        try:
            index = len(output_only_ids) - output_only_ids[::-1].index(151668)
        except ValueError:
            index = 0

        if enable_thinking:
            thinking_content = tokenizer.decode(
                output_only_ids[:index],
                skip_special_tokens=True
            ).strip("\n")
            content = tokenizer.decode(
                output_only_ids[index:],
                skip_special_tokens=True
            ).strip("\n")
        else:
            thinking_content = None
            content = tokenizer.decode(
                output_only_ids,
                skip_special_tokens=True
            ).strip("\n")

        responses.append({
            'thinking_content': thinking_content,
            'content': content
        })

    return responses

# %% [markdown]
# # Data

# %%
ds = datasets.load_dataset('gretelai/synthetic_text_to_sql', streaming=False)
ds_train, ds_test = ds['train'], ds['test']

ds_train_subset = ds_train.train_test_split(test_size=0.1, seed=42)['test']
split = ds_train_subset.train_test_split(test_size=0.025, seed=42)
ds_train = split['train']
ds_valid = split['test']

ds_train
# Out:
# Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#     num_rows: 9750
# })

# %%
# datasets for GRPO must include a column "prompt"
def construct_message(example):
    return {"prompt": [
        {"role": "system", "content": f"The user asks a question. Your task is to generate the SQL query to answer that question. Return SQL query only. The context of the question is the following: '{example['sql_context']}'"},
        {"role": "user", "content": example['sql_prompt']}
    ]}
ds_train = ds_train.map(construct_message)
ds_valid = ds_valid.map(construct_message)

# rename the ground_truth column
ds_train = ds_train.rename_column("sql", "ground_truth")
ds_valid = ds_valid.rename_column("sql", "ground_truth")

ds_train
# Out:
# Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'ground_truth', 'sql_explanation', 'prompt'],
#     num_rows: 9750
# })

# %% [markdown]
# # Reward function

# %%
rouge = evaluate.load("rouge")

def normalize_sql(sql):
    return sqlparse.format(sql, reindent=True, keyword_case='upper').strip()

def compute_rouge(reference, prediction):
    result = rouge.compute(predictions=[prediction], references=[reference])
    return result['rougeL']


def evaluate_sql_response(reference, prediction, sql_context):
    # ROUGE-L
    rouge_score = compute_rouge(reference, prediction)

    for ref, pred,  in zip(reference, prediction):
        # execution check
        try:
            conn = sqlite3.connect(":memory:")
            cursor = conn.cursor()
            
            cursor.executescript(sql_context)
            cursor.execute(reference)
            ref_result = cursor.fetchall()
            
            cursor.execute(prediction)
            model_result = cursor.fetchall()
            
            execution_match = ref_result == model_result
        except Exception:
            execution_match = False
        finally:
            conn.close()
        
        # final score
        if execution_match:
            final_score = 1.0
        else:
            final_score = 0.7 * rouge_score

    return {
        "rougeL": round(rouge_score, 4),
        "execution_match": execution_match,
        "final_score": final_score
    }


def reward_func(completions, ground_truth, sql_context, **kwargs):
    scores = [
        evaluate_sql_response(
            reference=reference,
            prediction=prediction[0]["content"],
            sql_context=context
        )["final_score"]
        for reference, prediction, context in zip(ground_truth, completions, sql_context)
    ]
    return scores

# %% [markdown]
# # Model

# %%
checkpoint = "Qwen/Qwen3-0.6B"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

tokenizer = AutoTokenizer.from_pretrained(checkpoint, padding_side='left')

model = AutoModelForCausalLM.from_pretrained(
    checkpoint,
    # attn_implementation="sdpa",
    device_map="auto",
    dtype=torch.float32,
    # quantization_config=bnb_config
)

model.config.use_cache = False
model.gradient_checkpointing_enable()
# model = prepare_model_for_kbit_training(model)
model.enable_input_require_grads()

get_vm_usage_metrics()
# Out:
# [2026-01-18 11:01:44] INFO modeling.py:1004: We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# CPU 0 load: 3.00
# CPU 1 load: 0.00
# CPU 2 load: 0.00
# CPU 3 load: 3.00
# RAM Total: 27.40 GB, Used: 2.27 GB
# GPU 0 (Tesla T4) load: 0.0%
# GPU 0 (Tesla T4) VRAM Total: 16384.0 MB, Used 3063.0 MB
# Disk Total: 60.95 GB, Used: 44.49 GB

# %% [markdown]
# # GRPO

# %%
torch.cuda.empty_cache()

timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
RUN_NAME = f'grpo-lora-lr1e5-epochs1-{timestamp}'
OUTPUT_DIR = './grpo-output'
RESUME_TRAINING = False

PER_DEVICE_BATCH_SIZE = 8
effective_batch_size = 16
epochs=1
learning_rate = 1e-5
warmup_ratio = 0.1
lora_r = 16*4
lora_alpha = 64*4
lora_dropout = 0.01

gradient_accumulation_steps = int(effective_batch_size / PER_DEVICE_BATCH_SIZE)

wandb.init(
    project=os.environ["WANDB_PROJECT"],
    name=RUN_NAME,
    # id=run_id ,         # resume previous run if available
    # resume="allow",    # allows resuming crashed run
)



training_args = GRPOConfig(
    output_dir=OUTPUT_DIR,
    
    chat_template_kwargs = {"enable_thinking": False},
    num_train_epochs=epochs,
    num_generations=8,
    # use_liger_kernel=True,
    
    per_device_train_batch_size=PER_DEVICE_BATCH_SIZE,
    gradient_accumulation_steps=gradient_accumulation_steps,
    learning_rate=learning_rate,
    lr_scheduler_type="cosine",
    warmup_ratio=warmup_ratio,
    save_strategy="steps",
    save_steps=30,
    save_total_limit=2,
    eval_strategy="steps",
    eval_steps=30,
    per_device_eval_batch_size=PER_DEVICE_BATCH_SIZE*4,
    eval_accumulation_steps=1,
    # eval_kwargs={"num_generations": 1},
    num_generations_eval=1,
    logging_strategy="steps",
    logging_steps=30,
    report_to=['wandb'],
    run_name=RUN_NAME,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    max_grad_norm=1,
    load_best_model_at_end=True,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    # generate_during_eval=True
)

peft_config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules='all-linear'
)
# model.requires_grad_(False)                     # freeze base weights (precautionary)
model_peft = get_peft_model(model, peft_config) # inject a LoRA adapter

trainer = GRPOTrainer(
    processing_class=tokenizer,
    model=model_peft,
    args=training_args,
    reward_funcs=[reward_func],
    train_dataset=ds_train,
    eval_dataset=ds_valid,
    # callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)


# Training setup summary
dataset_size = len(ds_train)
steps_per_epoch = dataset_size // (PER_DEVICE_BATCH_SIZE * gradient_accumulation_steps)
total_steps = steps_per_epoch * epochs
warmup_steps = int(total_steps * warmup_ratio)

print("===== Training Setup Summary =====")
print(f"Num epochs:            {epochs}")
print(f"Effective batch size:  {effective_batch_size}")
print(f"Per-device batch size: {PER_DEVICE_BATCH_SIZE}")
print(f"Gradient accumulation: {gradient_accumulation_steps}")
print(f"Dataset size:          {dataset_size}")
print(f"Steps per epoch:       {steps_per_epoch}")
print(f"Total training steps:  {total_steps}")
print(f"Warmup steps:          {warmup_steps}")
print(f"Logging steps:         {training_args.logging_steps}")
print("===================================")
print(f"Start time: {datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}")


# Training
last_checkpoint = None
if RESUME_TRAINING and os.path.isdir(OUTPUT_DIR):
    last_checkpoint = get_last_checkpoint(OUTPUT_DIR)

if last_checkpoint is not None:
    print(f"Resuming training from checkpoint: {last_checkpoint}")
    trainer.train(resume_from_checkpoint=last_checkpoint)
else:
    print("Starting fresh training run")
    trainer.train()

print(f"End time: {datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}")
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: olialeshka (olialeshka-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/home/olialeshka_1/wandb/run-20260118_110147-7ody90cx</code>
# Syncing run <strong><a href='https://wandb.ai/olialeshka-none/text-to-sql/runs/7ody90cx' target="_blank">grpo-lora-lr1e5-epochs1-2026-01-18_11-01-46</a></strong> to <a href='https://wandb.ai/olialeshka-none/text-to-sql' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/olialeshka-none/text-to-sql' target="_blank">https://wandb.ai/olialeshka-none/text-to-sql</a>
#  View run at <a href='https://wandb.ai/olialeshka-none/text-to-sql/runs/7ody90cx' target="_blank">https://wandb.ai/olialeshka-none/text-to-sql/runs/7ody90cx</a>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# [2026-01-18 11:01:49] INFO spawn.py:77: x86_64-linux-gnu-gcc -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -fPIC -c /tmp/tmpq70f7lt9/test.c -o /tmp/tmpq70f7lt9/test.o
# [2026-01-18 11:01:49] INFO spawn.py:77: x86_64-linux-gnu-gcc /tmp/tmpq70f7lt9/test.o -laio -o /tmp/tmpq70f7lt9/a.out
# /usr/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# [2026-01-18 11:01:49] INFO spawn.py:77: x86_64-linux-gnu-gcc -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -fPIC -c /tmp/tmp_zqbd7js/test.c -o /tmp/tmp_zqbd7js/test.o
# [2026-01-18 11:01:49] INFO spawn.py:77: x86_64-linux-gnu-gcc /tmp/tmp_zqbd7js/test.o -L/usr -L/usr/lib64 -lcufile -o /tmp/tmp_zqbd7js/a.out
# /usr/bin/ld: cannot find -lcufile: No such file or directory
# collect2: error: ld returned 1 exit status
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# ===== Training Setup Summary =====
# Num epochs:            1
# Effective batch size:  16
# Per-device batch size: 8
# Gradient accumulation: 2
# Dataset size:          9750
# Steps per epoch:       609
# Total training steps:  609
# Warmup steps:          60
# Logging steps:         30
# ===================================
# Start time: 2026-01-18_11-01-49
# Starting fresh training run
# [2026-01-18 11:01:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:01:55] INFO rouge_scorer.py:83: Using default tokenizer.
#     <div>
#
#       <progress value='886' max='4875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 886/4875 4:38:14 < 20:55:32, 0.05 it/s, Epoch 0.18/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30</td>
#       <td>0.014500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.039800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>-0.008200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.024600</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.001300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.020900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.038300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.013600</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.012500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>-0.015200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>-0.002800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.007300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.017200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.017400</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>-0.005700</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.016000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>-0.001400</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>-0.006600</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>-0.008500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.030800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.022900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>-0.003500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.009500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.017700</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.002800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.001700</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.002700</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>-0.002800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.007000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:02:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:03:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:04:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:05:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:06:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:07:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:08:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:09:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 11:10:11] INFO rouge_scorer.py:83: Using default tokenizer.
# ...
# [2026-01-18 12:09:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 12:09:45] INFO rouge_scorer.py:83: Using default tokenizer.
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:37:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:38:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:39:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-18 15:40:09] INFO rouge_scorer.py:83: Using default tokenizer.

# %%
# model.save_pretrained(f"{OUTPUT_DIR}/best_model")

# %% [markdown]
# # Test

# %%
OUTPUT_DIR = './grpo-output'
checkpoint = f"{OUTPUT_DIR}/checkpoint-4875/"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint, dtype=torch.float16).to(device)
model.eval()

ds = datasets.load_dataset('gretelai/synthetic_text_to_sql', streaming=False)
ds_train, ds_test = ds['train'], ds['test']


def construct_message(prompt, context):
    return [
        {"role": "system", "content": f"The user asks a question. Your task is to generate the SQL query to answer that question. Return SQL query only. The context of the question is the following: '{context}'"},
        {"role": "user", "content": prompt}
    ]

def generate_model_response_batch(messages_list, enable_thinking=True, max_new_tokens=512):
    texts = [
        tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=enable_thinking
        )
        for messages in messages_list
    ]

    model_inputs = tokenizer(
        texts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        padding_side='left'
    ).to(model.device)

    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=max_new_tokens
    )

    responses = []
    for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids):
        # Slice to get only generated part
        output_only_ids = output_ids[len(input_ids):].tolist()

        # Try to find `</think>` (id 151668)
        try:
            index = len(output_only_ids) - output_only_ids[::-1].index(151668)
        except ValueError:
            index = 0

        if enable_thinking:
            thinking_content = tokenizer.decode(
                output_only_ids[:index],
                skip_special_tokens=True
            ).strip("\n")
            content = tokenizer.decode(
                output_only_ids[index:],
                skip_special_tokens=True
            ).strip("\n")
        else:
            thinking_content = None
            content = tokenizer.decode(
                output_only_ids,
                skip_special_tokens=True
            ).strip("\n")

        responses.append({
            'thinking_content': thinking_content,
            'content': content
        })

    return responses


rouge = evaluate.load("rouge")

def normalize_sql(sql):
    return sqlparse.format(sql, reindent=True, keyword_case='upper').strip()

def compute_rouge(reference, prediction):
    result = rouge.compute(predictions=[prediction], references=[reference])
    return result['rougeL']

def evaluate_sql_response(reference, prediction, sql_context):
    # ROUGE-L
    rouge_score = compute_rouge(reference, prediction)
    
    # execution check
    try:
        conn = sqlite3.connect(":memory:")
        cursor = conn.cursor()
        
        cursor.executescript(sql_context)
        cursor.execute(reference)
        ref_result = cursor.fetchall()
        
        cursor.execute(prediction)
        model_result = cursor.fetchall()
        
        execution_match = ref_result == model_result
    except Exception:
        execution_match = False
    finally:
        conn.close()
    
    # final score
    if execution_match:
        final_score = 1.0
    else:
        final_score = 0.7 * rouge_score

    return {
        "rougeL": round(rouge_score, 4),
        "execution_match": execution_match,
        "final_score": final_score
    }

# %%
BATCH_SIZE = 32
ENABLE_THINKING = False
MAX_NEW_TOKENS = 512


prompts = [ds_test[id]['sql_prompt'] for id in range(len(ds_test))]
contexts = [ds_test[id]['sql_context'] for id in range(len(ds_test))]

responses = []
print(f"Start time: {time.ctime(time.time())}")
for i in tqdm(range(0, len(prompts), BATCH_SIZE)):
    batch_prompts = prompts[i : i + BATCH_SIZE]
    batch_contexts = contexts[i : i + BATCH_SIZE]

    messages_list = [
        construct_message(prompt=p, context=c)
        for p, c in zip(batch_prompts, batch_contexts)
    ]

    batch_responses = generate_model_response_batch(messages_list, enable_thinking=ENABLE_THINKING, max_new_tokens=MAX_NEW_TOKENS)

    responses.extend(batch_responses)

print(f"End time: {time.ctime(time.time())}")
# Out:
# Start time: Mon Jan 19 12:59:50 2026
#   0%|          | 0/183 [00:00<?, ?it/s]
# End time: Mon Jan 19 13:14:20 2026

# %%
references = [ds_test[id]['sql'] for id in range(len(ds_test))]
predictions = [responses[id]['content'] for id in range(len(ds_test))]

scores = [
    evaluate_sql_response(
        reference=reference,
        prediction=prediction,
        sql_context=context
    )
    for reference, prediction, context in tqdm(zip(references, predictions, contexts), total=len(ds_test))
]
# Out:
#   0%|          | 0/5851 [00:00<?, ?it/s]
# [2026-01-19 13:15:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:15:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:00] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:01] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:02] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:03] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:04] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:05] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:06] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:07] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:08] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:09] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:10] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:11] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:12] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:13] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:14] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:15] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:16] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:17] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:18] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:19] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:20] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:21] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:22] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:23] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:24] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:51] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:52] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:53] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:54] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:55] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:56] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:57] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:58] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:59] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:16:59] INFO rouge_scorer.py:83: Using default tokenizer.
# ...
# [2026-01-19 13:26:25] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:26] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:27] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:28] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:29] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:30] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:31] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:32] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:33] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:34] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:35] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:36] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:37] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:38] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:39] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:40] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:41] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:42] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:43] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:44] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:45] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:46] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:47] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:48] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:49] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:50] INFO rouge_scorer.py:83: Using default tokenizer.
# [2026-01-19 13:26:51] INFO rouge_scorer.py:83: Using default tokenizer.

# %%
print(f"Mean test set score: {np.mean([score['final_score'] for score in scores]):.3f}")
# Out:
# Mean test set score: 0.756
